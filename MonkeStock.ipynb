# %%
#Calculates anualized returns

# %%
import math
import pandas as pd
def load_data():
  url = 'https://en.wikipedia.org/wiki/List_of_S%26P_500_companies'
  html = pd.read_html(url, header = 0)
  df = html[0]
  return df

# %%
#def load_SPY():

# %%
stock = 'MMM'

# %%
df_spy = load_data()
df_spy
# Out:
#     Symbol              Security SEC filings             GICS Sector  \
# 0      MMM                    3M     reports             Industrials
# 1      AOS           A. O. Smith     reports             Industrials
# 2      ABT                Abbott     reports             Health Care
# 3     ABBV                AbbVie     reports             Health Care
# 4     ABMD               Abiomed     reports             Health Care
# ..     ...                   ...         ...                     ...
# 498    YUM           Yum! Brands     reports  Consumer Discretionary
# 499   ZBRA    Zebra Technologies     reports  Information Technology
# 500    ZBH         Zimmer Biomet     reports             Health Care
# 501   ZION  Zions Bancorporation     reports              Financials
# 502    ZTS                Zoetis     reports             Health Care
#
#                       GICS Sub-Industry    Headquarters Location  \
# 0              Industrial Conglomerates    Saint Paul, Minnesota
# ...

# %%
import yfinance as yf

# %%
list(df_spy.Symbol)
# Out:
# ['MMM',
#  'AOS',
#  'ABT',
#  'ABBV',
#  'ABMD',
#  'ACN',
#  'ATVI',
#  'ADM',
#  'ADBE',
#  'ADP',
#  'AAP',
#  'AES',
#  'AFL',
#  'A',
#  'APD',
#  'AKAM',
#  'ALK',
#  'ALB',
#  'ARE',
#  'ALGN',
#  'ALLE',
#  'LNT',
#  'ALL',
#  'GOOGL',
#  'GOOG',
#  'MO',
#  'AMZN',
#  'AMCR',
#  'AMD',
#  'AEE',
#  'AAL',
#  'AEP',
#  'AXP',
#  'AIG',
#  'AMT',
#  'AWK',
#  'AMP',
#  'ABC',
#  'AME',
#  'AMGN',
#  'APH',
#  'ADI',
#  'ANSS',
#  'AON',
#  'APA',
#  'AAPL',
#  'AMAT',
#  'APTV',
#  'ANET',
#  'AJG',
#  'AIZ',
#  'T',
#  'ATO',
#  'ADSK',
#  'AZO',
#  'AVB',
#  'AVY',
#  'BKR',
#  'BALL',
#  'BAC',
#  'BBWI',
#  'BAX',
#  'BDX',
#  'WRB',
#  'BRK.B',
#  'BBY',
#  'BIO',
#  'TECH',
#  'BIIB',
#  'BLK',
#  'BK',
#  'BA',
#  'BKNG',
#  'BWA',
#  'BXP',
#  'BSX',
#  'BMY',
#  'AVGO',
#  'BR',
#  'BRO',
#  'BF.B',
#  'CHRW',
#  'CDNS',
#  'CZR',
#  'CPT',
#  'CPB',
#  'COF',
#  'CAH',
#  'KMX',
#  'CCL',
#  'CARR',
#  'CTLT',
#  'CAT',
#  'CBOE',
#  'CBRE',
#  'CDW',
#  'CE',
# ...

# %%
spy = {'Symbol': '^GSPC'}
df_spy = df_spy.append(spy, ignore_index=True)
# Out:
# C:\Users\ryana\AppData\Local\Temp\ipykernel_6324\2449448430.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(spy, ignore_index=True)

# %%
data = yf.download(
    tickers=list(df_spy.Symbol),
    period = "1y",
    interval = "1d",
    group_by = 'ticker',
    auto_adjust = True,
    threads = True,
    proxy = None
)
# Out:
# [*********************100%***********************]  504 of 504 completed
#
# 2 Failed downloads:
# - BRK.B: No data found, symbol may be delisted
# - BF.B: No data found for this date range, symbol may be delisted

# %%
data
# Out:
#                   EPAM                                                \
#                   Open        High         Low       Close    Volume
# Date
# 2021-10-27  651.830017  659.469971  646.299988  652.359985  224300.0
# 2021-10-28  659.010010  672.119995  656.520020  670.530029  232500.0
# 2021-10-29  662.969971  674.809998  660.500000  673.239990  239700.0
# 2021-11-01  675.130005  675.130005  652.770020  659.650024  215400.0
# 2021-11-02  658.719971  675.849976  656.299988  674.330017  195300.0
# ...                ...         ...         ...         ...       ...
# 2022-10-21  331.459991  336.149994  324.859985  331.390015  502300.0
# 2022-10-24  331.160004  334.299988  320.480011  332.070007  265500.0
# 2022-10-25  335.079987  349.100006  334.029999  348.130005  327700.0
# 2022-10-26  342.350006  351.320007  342.350006  345.510010  241440.0
# 2021-10-26         NaN         NaN         NaN         NaN       NaN
#
# ...

# %%
data[stock]
# Out:
#                   Open        High         Low       Close     Volume
# Date
# 2021-10-27  175.475365  175.542748  171.441557  171.595596  2627000.0
# 2021-10-28  171.605190  173.299575  171.595568  173.164795  1944900.0
# 2021-10-29  173.010782  174.166046  171.480043  172.019165  2559500.0
# 2021-11-01  171.874774  173.039674  170.892794  172.885635  2010500.0
# 2021-11-02  173.280338  175.311682  172.914499  175.186523  2213000.0
# ...                ...         ...         ...         ...        ...
# 2022-10-21  113.150002  116.940002  113.050003  116.809998  3342000.0
# 2022-10-24  117.529999  119.139999  117.190002  118.379997  3394100.0
# 2022-10-25  113.510002  118.599998  113.150002  118.500000  5014700.0
# 2022-10-26  119.589996  123.290001  119.589996  122.699997  4625227.0
# 2021-10-26         NaN         NaN         NaN         NaN        NaN
#
# [253 rows x 5 columns]

# %%
df = pd.DataFrame(data[stock].Close)
df['Date'] = df.index
df
# Out:
#                  Close       Date
# Date
# 2021-10-27  171.595596 2021-10-27
# 2021-10-28  173.164795 2021-10-28
# 2021-10-29  172.019165 2021-10-29
# 2021-11-01  172.885635 2021-11-01
# 2021-11-02  175.186523 2021-11-02
# ...                ...        ...
# 2022-10-21  116.809998 2022-10-21
# 2022-10-24  118.379997 2022-10-24
# 2022-10-25  118.500000 2022-10-25
# 2022-10-26  122.699997 2022-10-26
# 2021-10-26         NaN 2021-10-26
#
# [253 rows x 2 columns]

# %%
df = pd.DataFrame(data[stock].Close.pct_change() * 100)
df['Date'] = df.index
df
# Out:
#                Close       Date
# Date
# 2021-10-27       NaN 2021-10-27
# 2021-10-28  0.914475 2021-10-28
# 2021-10-29 -0.661584 2021-10-29
# 2021-11-01  0.503706 2021-11-01
# 2021-11-02  1.330873 2021-11-02
# ...              ...        ...
# 2022-10-21  3.271149 2022-10-21
# 2022-10-24  1.344063 2022-10-24
# 2022-10-25  0.101371 2022-10-25
# 2022-10-26  3.544301 2022-10-26
# 2021-10-26  0.000000 2021-10-26
#
# [253 rows x 2 columns]

# %%
import random

df_spy = load_data()
symbol_list = list(df_spy.Symbol)
symbol1 = random.choice(symbol_list)
symbol2 = random.choice(symbol_list)
symbol3 = random.choice(symbol_list)

# %%
import matplotlib.pyplot as plt
from cProfile import label


def plotPerformance(arg):
    df = arg
    
    plt.figure(figsize=(16,9))

    #  subplot #2
    plt.subplot(222)
    plt.plot(df.index, data[symbol1].Close, label="".join(symbol1))
    plt.plot(df.index, data[symbol2].Close, label="".join(symbol2))
    plt.plot(df.index, data[symbol3].Close, label="".join(symbol3))
    plt.title("Random Stocks")
    plt.legend(loc="upper right")
    plt.xticks(rotation = 90)
    plt.show()  # plot subplots

# %%
plotPerformance(data)
